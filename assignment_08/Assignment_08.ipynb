# %% [markdown]
# <a href="https://colab.research.google.com/github/Zarak00/Data690_fall2022/blob/main/assignment_08/Assignment_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zarak Mahmood
# - Assignment 8
# - 10/22/2022

# %%
import pandas as pd
import plotly.express as px

# %%
#Importing data 

DATA_URL = "https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/assignments/assignment_08_census_cost/census_costs.txt"
df = pd.read_csv(DATA_URL, skiprows=1, sep="\t")

# %%
#Finding rows and columns 
df.shape
# Out:
# (23, 4)

# %% [markdown]
# # Finding first, last, and random rows

# %%
# Displaying First 10 rows
df.head(10)
# Out:
#   Census Year Total Population Census Cost Average Cost Per Person
# 0        1790        3,929,214     $44,377              1.13 cents
# 1        1800        5,308,483     $66,109              1.24 cents
# 2        1810        7,239,881    $178,445              2.46 cents
# 3        1820        9,633,822    $208,526              2.16 cents
# 4        1830       12,866,020    $378,545              2.94 cents
# 5        1840       17,069,458    $833,371              4.88 cents
# 6        1850       23,191,876  $1,423,351              6.14 cents
# 7        1860       31,443,321  $1,969,377              6.26 cents
# 8        1870       38,558,371  $3,421,198              8.87 cents
# 9        1880       50,155,783  $5,790,678             11.54 cents

# %%
# Displaying last 10 rows
df.tail(10)
# Out:
#    Census Year Total Population     Census Cost Average Cost Per Person
# 13        1920      105,710,620     $25,117,000             23.76 cents
# 14        1930      122,775,046     $40,156,000             32.71 cents
# 15        1940      131,669,275     $67,527,000             51.29 cents
# 16        1950      151,325,798     $91,462,000             60.44 cents
# 17        1960      179,323,175    $127,934,000             71.34 cents
# 18        1970      203,302,031    $247,653,000                   $1.22
# 19        1980      226,542,199  $1,078,488,000                   $4.76
# 20        1990      248,718,301  $2,492,830,000                  $10.02
# 21        2000      281,421,906    $4.5 Billion                  $15.99
# 22       2010*      308,745,538     $13 Billion                  $42.11

# %%
# Displaying 10 random
df.sample(10)
# Out:
#    Census Year Total Population     Census Cost Average Cost Per Person
# 10        1890       62,979,766     $11,547,127             18.33 cents
# 21        2000      281,421,906    $4.5 Billion                  $15.99
# 20        1990      248,718,301  $2,492,830,000                  $10.02
# 12        1910       91,972,266     $15,968,000             17.07 cents
# 13        1920      105,710,620     $25,117,000             23.76 cents
# 14        1930      122,775,046     $40,156,000             32.71 cents
# 11        1900       76,303,387     $11,854,000             15.54 cents
# 4         1830       12,866,020        $378,545              2.94 cents
# 3         1820        9,633,822        $208,526              2.16 cents
# 8         1870       38,558,371      $3,421,198              8.87 cents

# %% [markdown]
# # Finding info and stats

# %%
# Finding data type using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Census Year              23 non-null     object
#  1   Total Population         23 non-null     object
#  2   Census Cost              23 non-null     object
#  3   Average Cost Per Person  23 non-null     object
# dtypes: object(4)
# memory usage: 864.0+ bytes

# %%
# Finding stats of all columns 
df.describe()
# Out:
#        Census Year Total Population Census Cost Average Cost Per Person
# count           23               23          23                      23
# unique          23               23          23                      23
# top           1790        3,929,214     $44,377              1.13 cents
# freq             1                1           1                       1

# %% [markdown]
# # Cleanse the data to make the year, population, cost, cost per person numerical type

# %%
# Function to cleanse the column 
def cleanse_pop(a_string):
    return int(a_string.replace(",",""))

# %%
#Using the apply() method 
df["tot_pop"] = df["Total Population"].apply(cleanse_pop)

df.head()
# Out:
#   Census Year Total Population Census Cost Average Cost Per Person   tot_pop
# 0        1790        3,929,214     $44,377              1.13 cents   3929214
# 1        1800        5,308,483     $66,109              1.24 cents   5308483
# 2        1810        7,239,881    $178,445              2.46 cents   7239881
# 3        1820        9,633,822    $208,526              2.16 cents   9633822
# 4        1830       12,866,020    $378,545              2.94 cents  12866020

# %% [markdown]
# #summary statistics of the numerical columns - use describe() function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Census Year              23 non-null     object
#  1   Total Population         23 non-null     object
#  2   Census Cost              23 non-null     object
#  3   Average Cost Per Person  23 non-null     object
#  4   tot_pop                  23 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.0+ KB

# %%
df.describe()
# Out:
#             tot_pop
# count  2.300000e+01
# mean   1.039211e+08
# std    9.622629e+07
# min    3.929214e+06
# 25%    2.013067e+07
# 50%    7.630339e+07
# 75%    1.653245e+08
# max    3.087455e+08

# %%
df.describe(include="all")
# Out:
#        Census Year Total Population Census Cost Average Cost Per Person  \
# count           23               23          23                      23
# unique          23               23          23                      23
# top           1790        3,929,214     $44,377              1.13 cents
# freq             1                1           1                       1
# mean           NaN              NaN         NaN                     NaN
# std            NaN              NaN         NaN                     NaN
# min            NaN              NaN         NaN                     NaN
# 25%            NaN              NaN         NaN                     NaN
# 50%            NaN              NaN         NaN                     NaN
# 75%            NaN              NaN         NaN                     NaN
# max            NaN              NaN         NaN                     NaN
#
#              tot_pop
# count   2.300000e+01
# unique           NaN
# top              NaN
# freq             NaN
# mean    1.039211e+08
# std     9.622629e+07
# min     3.929214e+06
# 25%     2.013067e+07
# 50%     7.630339e+07
# 75%     1.653245e+08
# max     3.087455e+08

# %% [markdown]
# #Using plotly

# %%
fig = px.bar(
    df, 
    x="Census Year", 
    y="Average Cost Per Person", 
    title="Average cost per person over time", 
    color="Census Year",
    template="plotly_dark")

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d2a3d67b-9d61-4d39-a3a4-379b027aacc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2a3d67b-9d61-4d39-a3a4-379b027aacc2")) {                    Plotly.newPlot(                        "d2a3d67b-9d61-4d39-a3a4-379b027aacc2",                        [{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1790","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1790","offsetgroup":"1790","orientation":"v","showlegend":true,"textposition":"auto","x":["1790"],"xaxis":"x","y":["1.13 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1800","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1800","offsetgroup":"1800","orientation":"v","showlegend":true,"textposition":"auto","x":["1800"],"xaxis":"x","y":["1.24 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1810","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1810","offsetgroup":"1810","orientation":"v","showlegend":true,"textposition":"auto","x":["1810"],"xaxis":"x","y":["2.46 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1820","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1820","offsetgroup":"1820","orientation":"v","showlegend":true,"textposition":"auto","x":["1820"],"xaxis":"x","y":["2.16 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1830","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1830","offsetgroup":"1830","orientation":"v","showlegend":true,"textposition":"auto","x":["1830"],"xaxis":"x","y":["2.94 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1840","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"1840","offsetgroup":"1840","orientation":"v","showlegend":true,"textposition":"auto","x":["1840"],"xaxis":"x","y":["4.88 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1850","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"1850","offsetgroup":"1850","orientation":"v","showlegend":true,"textposition":"auto","x":["1850"],"xaxis":"x","y":["6.14 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1860","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"1860","offsetgroup":"1860","orientation":"v","showlegend":true,"textposition":"auto","x":["1860"],"xaxis":"x","y":["6.26 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1870","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"1870","offsetgroup":"1870","orientation":"v","showlegend":true,"textposition":"auto","x":["1870"],"xaxis":"x","y":["8.87 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Census Year=%{x}<br>Average Cost Per Person=%{y}<extra></extra>","legendgroup":"1880","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"1880","offsetgroup":"1880","orientation":"v","showlegend":true,"textposition":"auto","x":["1880"],"xaxis":"x","y":["11.54 cents"],"yaxis":"y","type":"bar"},{"alignmentgroup":"Tru ...

# %% [markdown]
# # Plot the scatter plot of Total Population vs Total Cost.

# %%
fig = px.scatter(
    df,
    x="Total Population",
    y="Census Cost", 
    title="Total Population vs Total Cost", 
    color="Total Population", 
    template="plotly_dark"
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a39ca076-5795-44c0-b9f7-a3d2f7ac61f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a39ca076-5795-44c0-b9f7-a3d2f7ac61f2")) {                    Plotly.newPlot(                        "a39ca076-5795-44c0-b9f7-a3d2f7ac61f2",                        [{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"3,929,214","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"3,929,214","orientation":"v","showlegend":true,"x":["3,929,214"],"xaxis":"x","y":["$44,377"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"5,308,483","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"5,308,483","orientation":"v","showlegend":true,"x":["5,308,483"],"xaxis":"x","y":["$66,109"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"7,239,881","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"7,239,881","orientation":"v","showlegend":true,"x":["7,239,881"],"xaxis":"x","y":["$178,445"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"9,633,822","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"9,633,822","orientation":"v","showlegend":true,"x":["9,633,822"],"xaxis":"x","y":["$208,526"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"12,866,020","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"12,866,020","orientation":"v","showlegend":true,"x":["12,866,020"],"xaxis":"x","y":["$378,545"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"17,069,458","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"17,069,458","orientation":"v","showlegend":true,"x":["17,069,458"],"xaxis":"x","y":["$833,371"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"23,191,876","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"23,191,876","orientation":"v","showlegend":true,"x":["23,191,876"],"xaxis":"x","y":["$1,423,351"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"31,443,321","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"31,443,321","orientation":"v","showlegend":true,"x":["31,443,321"],"xaxis":"x","y":["$1,969,377"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"38,558,371","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"38,558,371","orientation":"v","showlegend":true,"x":["38,558,371"],"xaxis":"x","y":["$3,421,198"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"50,155,783","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"50,155,783","orientation":"v","showlegend":true,"x":["50,155,783"],"xaxis":"x","y":["$5,790,678"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"62,979,766","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"62,979,766","orientation":"v","showlegend":true,"x":["62,979,766"],"xaxis":"x","y":["$11,547,127"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Total Population=%{x}<br>Census Cost=%{y}<extra></extra>","legendgroup":"76,303,387","marker":{"color":"#EF553B","symbol":"circ ...
