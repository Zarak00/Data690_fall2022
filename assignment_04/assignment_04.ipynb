# %% [markdown]
# <a href="https://colab.research.google.com/github/Zarak00/Data690_fall2022/blob/main/assignment_04/assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Zarak Mahmmod
#
# - Assignment 4
# - 9/25/2022

# %% [markdown]
# #Importing Pandas

# %%
import pandas as pd #importing pandas

print(pd.__version__)
# Out:
# 1.3.5

# %% [markdown]
# #Uploading file to colab

# %%
from google.colab import files #Imported csv file from local drive

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b72af8e3-6f9a-4c12-8e46-d39f0a35c5c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b72af8e3-6f9a-4c12-8e46-d39f0a35c5c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io                          #Code imported the csv file and made in readable               

df = pd.read_csv(io.BytesIO(uploaded['MERGED2017_18_PP.csv']))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# #Question 6 - Number of Rows and Columns

# %%
df.shape #Code shows number of rows and columns
# Out:
# (7112, 1986)

# %% [markdown]
# #Looking at the first 5 colleges

# %%
df.head() #code shows first 5 colleges, If no number is added it will show first 5
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# #Looking at the last 5 colleges

# %%
df.tail() #code shows last 5 colleges, If no number is added it will show first 5
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# #Looking 5 random colleges

# %%
df.sample(5)
# Out:
#       UNITID   OPEID  OPEID6                             INSTNM         CITY  \
# 1152  153001  184700    1847             Buena Vista University   Storm Lake
# 3342  220765  865500    8655  Genesis Career College-Cookeville   Cookeville
# 3423  224110  355800    3558        North Central Texas College  Gainesville
# 1617  167996  221700    2217                  Stonehill College       Easton
# 3420  223922  355400    3554                  Clarendon College    Clarendon
#
#      STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 1152     IA       50588           NaN      NaN     NaN  ...
# 3342     TN  38501-1907           NaN      NaN     NaN  ...
# 3423     TX  76240-4699           NaN      NaN     NaN  ...
# 1617     MA  02357-6110           NaN      NaN     NaN  ...
# 3420     TX       79226           NaN      NaN     NaN  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN  G12MN  \
# ...

# %% [markdown]
# #Question 7 - Creating a smaller data frame for 9 variables

# %%
small_df = df[['UNITID', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'ADM_RATE', 'UGDS', 'TUITIONFEE_IN', 'MN_EARN_WNE_P10']]

print("Smaller DataFrame:")

print(small_df.head())
# Out:
# Smaller DataFrame:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0    0.9027   4824.0         9857.0              NaN
# 1    0.9181  12866.0         8328.0              NaN
# 2       NaN    318.0         6900.0              NaN
# 3    0.8123   6917.0        10280.0              NaN
# 4    0.9787   4189.0        11068.0              NaN

# %% [markdown]
# #Question 9 : Definitions
#
# - UNTID - stands for unit id for insititution.
# - INSTNM - stands for insititution name.
# - City -  in the city where the insititution in located.
# - Zip - stands for the zip code of the insititution.
# - ADM_RATE - stands for admission rate
# - UGDS - stands for Enrollment of undergraduate certificate/degree-seeking students
# - TUITIONFEE_IN - In-state tuition and fees
# - MN_EARN_WNE_P10 - 10_yrs_after_entry.working_not_enrolled.mean_earnings

# %% [markdown]
# #Question 10 Explore smaller data set

# %% [markdown]
# #Look at the first 10 colleges

# %%
small_df.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# #Look at the last 10 colleges

# %%
small_df.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# #Look at the 10 random sample

# %%
small_df.sample(10)
# Out:
#         UNITID                                        INSTNM           CITY  \
# 1841    175980                              Millsaps College        Jackson
# 3643    231882                    Danville Community College       Danville
# 2237    190293  Continental School of Beauty Culture-Buffalo        Buffalo
# 3277    219213      National American University-Sioux Falls    Sioux Falls
# 4217    373058                  Vatterott College-Des Moines     Des Moines
# 293     113856                      East Los Angeles College  Monterey Park
# 941     144564               Danville Area Community College       Danville
# 6757  15085301       PJ's College of Cosmetology- Brownsburg     Brownsburg
# 3590    230205           Evans Hairstyling College-St George   Saint George
# 2205    189404                       Brittany Beauty Academy       Brooklyn
#
#      STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# ...

# %% [markdown]
# #Find and display UMBC

# %%
UMBC_df_filtered = small_df[df['INSTNM'] == 'University of Maryland-Baltimore County']
UMBC_df_filtered
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %% [markdown]
# #Find and display Maryland College Park

# %%
UMD_df_filtered = small_df[df['INSTNM'] == 'University of Maryland-College Park']
UMD_df_filtered
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %% [markdown]
# #Find and display Loyola College Maryland

# %%
LC_df_filtered = small_df[df['INSTNM'] == 'Loyola College Maryland']
LC_df_filtered
# Out:
# Empty DataFrame
# Columns: [UNITID, INSTNM, CITY, STABBR, ZIP, ADM_RATE, UGDS, TUITIONFEE_IN, MN_EARN_WNE_P10]
# Index: []

# %% [markdown]
# #Find and display Johns Hopkins

# %%
JH_df_filtered = small_df[df['INSTNM'] == 'Johns Hopkins University']
JH_df_filtered
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %% [markdown]
# #Question 11 Only current states in the data

# %%
state_df_filtered = small_df[df['STABBR'].str.contains('MD|VA|PA|DE|DC')] #code to filter states
state_df_filtered
# Out:
#         UNITID                                             INSTNM  \
# 634     130837  Margaret H Rollins School of Nursing at Beebe ...
# 635     130873                          Dawn Career Institute LLC
# 636     130907         Delaware Technical Community College-Terry
# 637     130934                          Delaware State University
# 638     130943                             University of Delaware
# ...        ...                                                ...
# 7063  45794301   Somerset County Technology Center - Bedford Site
# 7084  47503303      Relay Graduate School of Education - Delaware
# 7089  47503308  Relay Graduate School of Education - Philadelp...
# 7094  47503313  Relay Graduate School of Education - Washingto...
# 7103  48305401             Barber School of Pittsburgh - Ambridge
#
#               CITY STABBR        ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 634          Lewes     DE      19958       NaN     59.0            NaN
# ...

# %%
state_df_filtered.to_csv("Five_States_Colleges.csv") #code to download csv file

# %% [markdown]
# # Calculate the min, max, and average in-state tution of the above four institutions.

# %%
new_df = small_df[df['INSTNM'].str.contains('Johns Hopkins University|Loyola College Maryland|University of Maryland-College Park|University of Maryland-Baltimore County')] #code to filter states

# created a new data frame consisting of only for Universities that were required

# %%
print(new_df)
# Out:
#       UNITID                                   INSTNM          CITY STABBR  \
# 1473  162928                 Johns Hopkins University     Baltimore     MD
# 1478  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1479  163286      University of Maryland-College Park  College Park     MD
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473  21218-2688    0.1254   5663.0        52170.0              NaN
# 1478       21250    0.6021  11130.0        11518.0              NaN
# 1479       20742    0.4450  29273.0        10399.0              NaN

# %%
new_df.describe() # using the code to show the the stats of the data frame
# Out:
#               UNITID  ADM_RATE          UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# count       3.000000  3.000000      3.000000       3.000000              0.0
# mean   163160.666667  0.390833  15355.333333   24695.666667              NaN
# std       201.696141  0.242922  12359.130485   23800.047990              NaN
# min    162928.000000  0.125400   5663.000000   10399.000000              NaN
# 25%    163098.000000  0.285200   8396.500000   10958.500000              NaN
# 50%    163268.000000  0.445000  11130.000000   11518.000000              NaN
# 75%    163277.000000  0.523550  20201.500000   31844.000000              NaN
# max    163286.000000  0.602100  29273.000000   52170.000000              NaN
